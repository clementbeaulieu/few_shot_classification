# %% [markdown]
# <a href="https://colab.research.google.com/github/clementbeaulieu/few_shot_classification/blob/main/few_shot_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cloning Github Repository and Initialization

# %%
# Get GPU infos (Google Collab Pro Version)

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# Get Memory infos (Google Collab Pro Version)
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Fri May 20 08:09:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/clementbeaulieu/few_shot_classification.git
# Out:
# Cloning into 'few_shot_classification'...
# remote: Enumerating objects: 288, done.
# remote: Counting objects: 100% (288/288), done.
# remote: Compressing objects: 100% (205/205), done.
# remote: Total 288 (delta 120), reused 229 (delta 64), pack-reused 0
# Receiving objects: 100% (288/288), 103.37 KiB | 6.89 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
cd /content/few_shot_classification/
# Out:
# /content/few_shot_classification

# %%
# !pip install tensorboardX
# !pip install -U PyYAML
# Out:
# ...
#      |████████████████████████████████| 125 kB 8.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 7.6 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
#rm -rf few_shot_classification/

# %% [markdown]
# # Training 5 way 1 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_1_shot_batch100_epoch50 --gpu=0,1 --meta --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_1_shot_batch100_epoch50 --gpu=0,1 --meta --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_1_shot_batch100_epoch50 --gpu=0,1 --meta --tensorboard --load best --test
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_1_shot_batch100_epoch50 --gpu=0,1 --meta --tensorboard --load best --test
# ...

# %% [markdown]
# # Training 3 way 1 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 3_way_1_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 3 --val-n_way 3 --test-n_way 3 --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 3_way_1_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 3 --val-n_way 3 --test-n_way 3 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 3_way_1_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 3 --val-n_way 3 --test-n_way 3 --tensorboard --load best --test --epoch 1
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 3_way_1_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 3 --val-n_way 3 --test-n_way 3 --tensorboard --load best --test --epoch 1
# ...

# %% [markdown]
# # Training 2 way 1 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_1_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --val-n_way 2 --test-n_way 2 --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_1_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --val-n_way 2 --test-n_way 2 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_1_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --val-n_way 2 --test-n_way 2 --tensorboard --load best --test --epoch 1
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_1_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --val-n_way 2 --test-n_way 2 --tensorboard --load best --test --epoch 1
# ...

# %% [markdown]
# # Training 5 way 5 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_5_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 5 --val-n_way 5 --val-n_shot 5 --test-n_way 5 --test-n_shot 5  --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_5_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 5 --val-n_way 5 --val-n_shot 5 --test-n_way 5 --test-n_shot 5 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_5_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 5 --val-n_way 5 --val-n_shot 5 --test-n_way 5 --test-n_shot 5 --tensorboard --load best --test --epoch 1
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_5_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 5 --val-n_way 5 --val-n_shot 5 --test-n_way 5 --test-n_shot 5 --tensorboard --load best --test --epoch 1
# ...

# %% [markdown]
# # Training 5 way 10 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_10_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 10 --val-n_way 5 --val-n_shot 10 --test-n_way 5 --test-n_shot 10  --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_10_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 10 --val-n_way 5 --val-n_shot 10 --test-n_way 5 --test-n_shot 10 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_10_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 10 --val-n_way 5 --val-n_shot 10 --test-n_way 5 --test-n_shot 10 --tensorboard --load best --test --epoch 1
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_10_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 10 --val-n_way 5 --val-n_shot 10 --test-n_way 5 --test-n_shot 10 --tensorboard --load best --test --epoch 1
# ...

# %% [markdown]
# # Training 2 way 5 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_5_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 5 --val-n_way 2 --val-n_shot 5 --test-n_way 2 --test-n_shot 5  --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_5_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 5 --val-n_way 2 --val-n_shot 5 --test-n_way 2 --test-n_shot 5 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_5_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 5 --val-n_way 2 --val-n_shot 5 --test-n_way 2 --test-n_shot 5  --tensorboard --load best --test
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_5_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 5 --val-n_way 2 --val-n_shot 5 --test-n_way 2 --test-n_shot 5 --tensorboard --load best --test
# ...

# %% [markdown]
# # Training 2 way 10 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_10_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 10 --val-n_way 2 --val-n_shot 10 --test-n_way 2 --test-n_shot 10  --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_10_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 10 --val-n_way 2 --val-n_shot 10 --test-n_way 2 --test-n_shot 10 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_10_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 10 --val-n_way 2 --val-n_shot 10 --test-n_way 2 --test-n_shot 10  --tensorboard --load best --test
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_10_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 10 --val-n_way 2 --val-n_shot 10 --test-n_way 2 --test-n_shot 10 --tensorboard --load best --test
# ...

# %% [markdown]
# # Training 5 way 1 shot classification ResNet12 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --tag resnet12 --gpu=0,1,2,3 --meta --train-n_batch 20 --train-n_way 5 --train-n_shot 1 --val-n_batch 20 --val-n_way 5 --val-n_shot 1 --test-n_batch 20 --test-n_way 5 --test-n_shot 1 --encoder resnet12 --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --tag resnet12 --gpu=0,1,2,3 --meta --train-n_batch 20 --train-n_way 5 --train-n_shot 1 --val-n_batch 20 --val-n_way 5 --val-n_shot 1 --test-n_batch 20 --test-n_way 5 --test-n_shot 1 --encoder resnet12 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --tag resnet12 --gpu=0,1,2,3 --meta --train-n_batch 20 --train-n_way 5 --train-n_shot 1 --val-n_batch 20 --val-n_way 5 --val-n_shot 1 --test-n_batch 20 --test-n_way 5 --test-n_shot 1 --encoder resnet12 --tensorboard --load best --test --epoch 1
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --tag resnet12 --gpu=0,1,2,3 --meta --train-n_batch 20 --train-n_way 5 --train-n_shot 1 --val-n_batch 20 --val-n_way 5 --val-n_shot 1 --test-n_batch 20 --test-n_way 5 --test-n_shot 1 --encoder resnet12 --tensorboard --load best --test --epoch 1
# ...

# %% [markdown]
# # Training 5 way 2 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_2_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 2 --val-n_way 5 --val-n_shot 2 --test-n_way 5 --test-n_shot 2  --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_2_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 2 --val-n_way 5 --val-n_shot 2 --test-n_way 5 --test-n_shot 2 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_2_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 2 --val-n_way 5 --val-n_shot 2 --test-n_way 5 --test-n_shot 2  --tensorboard --load best --test
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 5_way_2_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 5 --train-n_shot 2 --val-n_way 5 --val-n_shot 2 --test-n_way 5 --test-n_shot 2 --tensorboard --load best --test
# ...

# %% [markdown]
# # Training 2 way 2 shot classification ConvNet4 (batch size = 100, episodes = 4, epoch = 50)

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_2_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 2 --val-n_way 2 --val-n_shot 2 --test-n_way 2 --test-n_shot 2  --tensorboard --val
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_2_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 2 --val-n_way 2 --val-n_shot 2 --test-n_way 2 --test-n_shot 2 --tensorboard --val
# ...

# %%
# !python3 run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_2_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 2 --val-n_way 2 --val-n_shot 2 --test-n_way 2 --test-n_shot 2  --tensorboard --load best --test
# Out:
# run.py --root-dir /content/drive/MyDrive/data --config /content/few_shot_classification/configs/convnet4/mini_imagenet/5_way_1_shot/reproduce_maml.yaml --name 2_way_2_shot_batch100_epoch50 --gpu=0,1,2,3 --meta --train-n_way 2 --train-n_shot 2 --val-n_way 2 --val-n_shot 2 --test-n_way 2 --test-n_shot 2 --tensorboard --load best --test
# ...
